# %% [markdown]
# # Datos inmobiliarios de California

# %%
# Cargamos librerías a utilisar
import numpy as np # librería numérica
import pandas as pd # librería para marcos de datos

# %%
# Cargamos datos inmobiliarios de Caliornia
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
# Generamos marcos de datos para el problema de regresión
X = pd.DataFrame(housing.data,columns = housing.feature_names)
y = pd.DataFrame(housing.target,columns = housing.target_names)

# %%
# Observamos las variables predictoras / features
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Hay 20640 observaciones
X.shape
# Out:
# (20640, 8)

# %%
# Observamos las variables respuesta
y.head()
# Out:
#    MedHouseVal
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422

# %%
# Cargamos librería para estandarizar los datos
from sklearn.preprocessing import StandardScaler

# %%
# Estandarizamos los features
feat_scaler = StandardScaler()# Resta la media y divide por la desviación estándar
feat_scaler.fit(X)
# Out:
# StandardScaler()

# %%
X = feat_scaler.transform(X)

# %%
# Estandarizamos las responses
resp_scaler = StandardScaler()
resp_scaler.fit(y)
# Out:
# StandardScaler()

# %%
y = resp_scaler.transform(y)

# %%
# Dividimos los datos para entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 111)

# %%
# Hay 15480 observaciones para entrenamiento
X_train.shape
# Out:
# (15480, 8)

# %% [markdown]
# # Modelos lineales regularizados/penalizados

# %%
# Corremos regresión lineal
from sklearn.linear_model import LinearRegression
lin_reg =LinearRegression()
lin_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
from sklearn.metrics import mean_squared_error

# %%
y_lin_pred = lin_reg.predict(X_test)
loss_lin = mean_squared_error(y_test,y_lin_pred)
loss_lin
# Out:
# 0.40192750313229725

# %%
# Corremos rgresión ridge con distintos valores de penalización
from sklearn.linear_model import Ridge
rid_reg = Ridge()
alphas = {'alpha':[1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100]} # Malla para grid search

# %%
# y elegimos la penalizacion mediante validación cruzada en los datos de prueba
from sklearn.model_selection import GridSearchCV

# %%
rid_reg_cv = GridSearchCV(rid_reg,alphas,scoring='neg_mean_squared_error',cv=10)
rid_reg_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')

# %%
# Let's check out the best parameter and the score
print(rid_reg_cv.best_params_) #Checamos cual es el mejor modelo
print(rid_reg_cv.best_score_)
# Out:
# {'alpha': 45}
# -0.39606446784925325

# %%
rid_reg = rid_reg_cv.best_estimator_

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
y_rid_pred = rid_reg.predict(X_test)
loss_rid = mean_squared_error(y_test,y_rid_pred)
loss_rid
# Out:
# 0.40271523250867686

# %%
# Corremos rgresión Lasso con distintos valores de penalización
# y elegimos la penalización con validación cruzada
from sklearn.linear_model import Lasso
lasso_reg = Lasso()
lasso_reg_cv = GridSearchCV(lasso_reg,alphas,scoring='neg_mean_squared_error',cv=10)
lasso_reg_cv.fit(X_train,y_train)
# Out:
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.362e+01, tolerance: 1.384e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.107e+01, tolerance: 1.390e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.476e+01, tolerance: 1.387e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.766e+01, tolerance: 1.383e+00
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=10, estimator=Lasso(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.001, 0.01, 1, 5, 10,
#                                    20, 30, 35, 40, 45, 50, 55, 100]},
#              scoring='neg_mean_squared_error')

# %%
# Let's check out the best parameter and the score
print(lasso_reg_cv.best_params_)
print(lasso_reg_cv.best_score_)
# Out:
# {'alpha': 0.001}
# -0.3958420529296844

# %%
lasso_reg = rid_reg_cv.best_estimator_

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
y_lasso_pred = lasso_reg.predict(X_test)
loss_lasso = mean_squared_error(y_test,y_lasso_pred)
loss_lasso
# Out:
# 0.40271523250867686

# %%
# El modelo lineal en este caso tiene el mejor error cuadrático medio
loss_lin < np.minimum(loss_lasso,loss_rid)
# Out:
# True

# %% [markdown]
# # Modelos polinomiales regularizados/penalizados

# %%
# Añadimos predictores para regresión polinomial
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)
X = poly.fit_transform(X) # Me añade los terminos polinomiales de orden 2

# %%
# Ahoara utilizamos 45 features
X.shape  #Tengo 1081 features
# Out:
# (20640, 1081)

# %%
# Dividimos nuevamente los datos para entrenamiento y prueba
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.25,random_state = 11)

# %%
# Corremos regresión polinomial
from sklearn.linear_model import LinearRegression
pol_reg =LinearRegression()
pol_reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
y_pol_pred = pol_reg.predict(X_test)
loss_pol = mean_squared_error(y_test,y_pol_pred)
loss_pol
# Out:
# 4156094.787402679

# %%
# Corremos regresión polinomial ridge
# y elegimos la penalizacion mediante validación cruzada en los datos de prueba
rid_reg = Ridge()
rid_pol_reg_cv = GridSearchCV(rid_reg,alphas,scoring='neg_mean_squared_error',cv=10)
rid_pol_reg_cv.fit(X_train,y_train)
rid_pol_reg = rid_pol_reg_cv.best_estimator_
# Out:
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.56077e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.57302e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.54052e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 5
#       3 rid_reg = Ridge()
#       4 rid_pol_reg_cv = GridSearchCV(rid_reg,alphas,scoring='neg_mean_squared_error',cv=10)
# ----> 5 rid_pol_reg_cv.fit(X_train,y_train)
#       6 rid_pol_reg = rid_pol_reg_cv.best_estimator_
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
#    1020 # multimetric is determined here because in the case of a callable
#    1021 # self.scoring the return type is only known after calling
#    1022 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1572, in GridSearchCV._run_search(self, evaluate_candidates)
#    1570 def _run_search(self, evaluate_candidates):
#    1571     """Search all candidates in param_grid"""
# -> 1572     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:964, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     956 if self.verbose > 0:
#     957     print(
#     958         "Fitting {0} folds for each of {1} candidates,"
#     959         " totalling {2} fits".format(
#     960             n_splits, n_candidates, n_candidates * n_splits
#     961         )
#     962     )
# --> 964 out = parallel(
#     965     delayed(_fit_and_score)(
#     966         clone(base_estimator),
#     967         X,
#     968         y,
#     969         train=train,
#     970         test=test,
#     971         parameters=parameters,
#     972         split_progress=(split_idx, n_splits),
#     973         candidate_progress=(cand_idx, n_candidates),
#     974         **fit_and_score_kwargs,
#     975     )
#     976     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     977         enumerate(candidate_params),
#     978         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     979     )
#     980 )
#     982 if len(out) < 1:
#     983     raise ValueError(
#     984         "No fits were performed. "
#     985         "Was the CV iterator empty? "
#     986         "Were there no candidates?"
#     987     )
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:1251, in Ridge.fit(self, X, y, sample_weight)
#    1241 xp, _ = get_namespace(X, y, sample_weight)
#    1242 X, y = self._validate_data(
#    1243     X,
#    1244     y,
#    (...)
#    1249     y_numeric=True,
#    1250 )
# -> 1251 return super().fit(X, y, sample_weight=sample_weight)
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:994, in _BaseRidge.fit(self, X, y, sample_weight)
#     990     else:
#     991         # for dense matrices or when intercept is set to 0
#     992         params = {}
# --> 994     self.coef_, self.n_iter_, self.solver_ = _ridge_regression(
#     995         X,
#     996         y,
#     997         alpha=self.alpha,
#     998         sample_weight=sample_weight,
#     999         max_iter=self.max_iter,
#    1000         tol=self.tol,
#    1001         solver=solver,
#    1002         positive=self.positive,
#    1003         random_state=self.random_state,
#    1004         return_n_iter=True,
#    1005         return_intercept=False,
#    1006         return_solver=True,
#    1007         check_input=False,
#    1008         fit_intercept=self.fit_intercept,
#    1009         **params,
#    1010     )
#    1011     self._set_intercept(X_offset, y_offset, X_scale)
#    1013 return self
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:753, in _ridge_regression(X, y, alpha, sample_weight, solver, max_iter, tol, verbose, positive, random_state, return_n_iter, return_intercept, return_solver, X_scale, X_offset, check_input, fit_intercept)
#     751 else:
#     752     try:
# --> 753         coef = _solve_cholesky(X, y, alpha)
#     754     except linalg.LinAlgError:
#     755         # use SVD solver if matrix is singular
#     756         solver = "svd"
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:209, in _solve_cholesky(X, y, alpha)
#     206 n_features = X.shape[1]
#     207 n_targets = y.shape[1]
# --> 209 A = safe_sparse_dot(X.T, X, dense_output=True)
#     210 Xy = safe_sparse_dot(X.T, y, dense_output=True)
#     212 one_alpha = np.array_equal(alpha, len(alpha) * [alpha[0]])
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:208, in safe_sparse_dot(a, b, dense_output)
#     204 else:
#     205     ret = a @ b
#     207 if (
# --> 208     sparse.issparse(a)
#     209     and sparse.issparse(b)
#     210     and dense_output
#     211     and hasattr(ret, "toarray")
#     212 ):
#     213     return ret.toarray()
#     214 return ret
#
# File c:\Users\ferna\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1513, in issparse(x)
#    1508     pass
#    1510 sparray.__doc__ = _spbase.__doc__
# -> 1513 def issparse(x):
#    1514     """Is `x` of a sparse array or sparse matrix type?
#    1515
#    1516     Parameters
#    (...)
#    1537     False
#    1538     """
#    1539     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
y_rid_pol_pred = rid_pol_reg.predict(X_test)
loss_rid_pol = mean_squared_error(y_test,y_rid_pol_pred)
loss_rid_pol
# Out:
# 0.3590362444357679

# %%
# Corremos regresión polinomial Lasso
# y elegimos la penalizacion mediante validación cruzada en los datos de prueba
lasso_reg = Lasso()
lasso_pol_reg_cv = GridSearchCV(lasso_reg,alphas,scoring='neg_mean_squared_error',cv=10)
lasso_pol_reg_cv.fit(X_train,y_train)
lasso_pol_reg = lasso_pol_reg_cv.best_estimator_
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e+03, tolerance: 1.392e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.143e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.150e+03, tolerance: 1.386e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.142e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.169e+03, tolerance: 1.389e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.165e+03, tolerance: 1.395e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.152e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.157e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e+03, tolerance: 1.377e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e+03, tolerance: 1.392e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.143e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.150e+03, tolerance: 1.386e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.142e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.169e+03, tolerance: 1.389e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.165e+03, tolerance: 1.395e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.152e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.157e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e+03, tolerance: 1.377e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.085e+03, tolerance: 1.392e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.143e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.150e+03, tolerance: 1.386e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.142e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.169e+03, tolerance: 1.389e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.165e+03, tolerance: 1.395e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.152e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.157e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e+03, tolerance: 1.377e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e+03, tolerance: 1.392e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.978e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.490e+03, tolerance: 1.386e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.526e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.756e+03, tolerance: 1.389e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.773e+03, tolerance: 1.395e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.543e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.663e+03, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.554e+03, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.050e+03, tolerance: 1.377e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.956e+02, tolerance: 1.392e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.427e+02, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.663e+02, tolerance: 1.386e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.943e+02, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.759e+02, tolerance: 1.395e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.671e+02, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.905e+02, tolerance: 1.393e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.485e+02, tolerance: 1.391e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.674e+02, tolerance: 1.377e+00
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.966e+02, tolerance: 1.544e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# Evaluamos el error cuadrático medio en los datos de prueba
y_lasso_pol_pred = lasso_pol_reg.predict(X_test)
loss_lasso_pol = mean_squared_error(y_test,y_lasso_pol_pred)
loss_lasso_pol
# Out:
# 0.40428115333570996

# %%
loss_rid_pol < loss_lasso_pol < loss_pol
# Out:
# True

# %%
loss_rid_pol < loss_lin
# Out:
# True
